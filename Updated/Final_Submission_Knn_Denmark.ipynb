# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="marketplace"](area);
 way["amenity"="marketplace"](area);
 rel["amenity"="marketplace"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data=response.json()
df = pd.DataFrame(data['elements'])

# %%
df.head()
# Out:
#    type         id        lat       lon  \
# 0  node  148680663  47.555612  9.688680
# 1  node  240937972  50.965496  7.182850
# 2  node  255897613  49.880786  8.660928
# 3  node  276043329  53.327598  9.878438
# 4  node  293994974  53.093369  8.810666
#
#                                                 tags
# 0  {'amenity': 'marketplace', 'description': 'Ler...
# 1  {'amenity': 'marketplace', 'name': 'Burgwinkel...
# 2  {'addr:city': 'Darmstadt', 'amenity': 'marketp...
# 3   {'amenity': 'marketplace', 'name': 'Marktplatz'}
# 4  {'amenity': 'marketplace', 'name': 'Findorffma...

# %%
df['tags'] = 'marketplace'

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="fuel"](area);
 way["amenity"="fuel"](area);
 rel["amenity"="fuel"](area);
);
out center;
"""
response1 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data1=response1.json()
df1 = pd.DataFrame(data1['elements'])
df1['tags'] = 'fuel'
df.head()
# Out:
#    type         id        lat       lon         tags
# 0  node  148680663  47.555612  9.688680  marketplace
# 1  node  240937972  50.965496  7.182850  marketplace
# 2  node  255897613  49.880786  8.660928  marketplace
# 3  node  276043329  53.327598  9.878438  marketplace
# 4  node  293994974  53.093369  8.810666  marketplace

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="cafe"](area);
 way["amenity"="cafe"](area);
 rel["amenity"="cafe"](area);
);
out center;
"""
response2 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data2=response2.json()
df2 = pd.DataFrame(data2['elements'])
df2['tags'] = 'cafe'
df2.head()
# Out:
#    type        id        lat        lon  tags
# 0  node    661339  48.103939  11.488255  cafe
# 1  node  21257562  50.859025  13.167652  cafe
# 2  node  26309934  50.119731  11.388971  cafe
# 3  node  29991932  49.015536   8.397546  cafe
# 4  node  30012754  52.538855  13.396097  cafe

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="parking"](area);
 way["amenity"="parking"](area);
 rel["amenity"="parking"](area);
);
out center;
"""
response3 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data3=response3.json()
df3 = pd.DataFrame(data3['elements'])
df3['tags'] = 'parking'
df3.head()
# Out:
#    type       id        lat       lon     tags
# 0  node   531550  49.878222  8.657972  parking
# 1  node   631662  49.813508  8.648890  parking
# 2  node   651192  49.881361  8.646917  parking
# 3  node  2455376  50.003178  8.990831  parking
# 4  node  9323857  47.714818  7.653783  parking

# %%
new = pd.concat([df,df1,df2,df3],axis=0)

# %%
new.head()
# Out:
#    type         id        lat       lon         tags
# 0  node  148680663  47.555612  9.688680  marketplace
# 1  node  240937972  50.965496  7.182850  marketplace
# 2  node  255897613  49.880786  8.660928  marketplace
# 3  node  276043329  53.327598  9.878438  marketplace
# 4  node  293994974  53.093369  8.810666  marketplace

# %%
new.to_csv("try.csv")

# %%
df=df1=df2=df3=[]
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="school"](area);
 way["amenity"="school"](area);
 rel["amenity"="school"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data=response.json()
df = pd.DataFrame(data['elements'])
df['tags'] = 'school'
df.head()
# Out:
#    type        id        lat       lon    tags
# 0  node  24470269  48.976183  8.414097  school
# 1  node  25929965  49.009291  8.432334  school
# 2  node  25976049  51.449116  6.660396  school
# 3  node  26009648  51.450805  6.647221  school
# 4  node  26009799  51.456106  6.654199  school

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="bank"](area);
 way["amenity"="bank"](area);
 rel["amenity"="bank"](area);
);
out center;
"""
response1 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data1=response1.json()
df1 = pd.DataFrame(data1['elements'])
df1['tags'] = 'bank'
df1.head()
# Out:
#    type        id        lat       lon  tags
# 0  node  16463150  49.550363  8.672208  bank
# 1  node  25185398  48.972136  8.404875  bank
# 2  node  25187718  48.971007  8.404962  bank
# 3  node  25508365  48.953803  8.508875  bank
# 4  node  25508368  48.953083  8.509484  bank

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="theatre"](area);
 way["amenity"="theatre"](area);
 rel["amenity"="theatre"](area);
);
out center;
"""
response2 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data2=response2.json()
df2 = pd.DataFrame(data2['elements'])
df2['tags'] = 'theatre'
df2.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-0b0879a4a8d5> in <module>
#      11 response2 = requests.get(overpass_url,
#      12                         params={'data': overpass_query})
# ---> 13 data2=response2.json()
#      14 df2 = pd.DataFrame(data2['elements'])
#      15 df2['tags'] = 'theatre'
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="post_office"](area);
 way["amenity"="post_office"](area);
 rel["amenity"="post_office"](area);
);
out center;
"""
response3 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data3=response3.json()
df3 = pd.DataFrame(data3['elements'])
df3['tags'] = 'post_office'
df3.head()

# %%
new1 = pd.concat([new,df,df1,df2,df3],axis=0)
new1.to_csv("Data_1.csv")

# %% [markdown]
# ## OLD

# %%
df_target=pd.read_csv('Data_1.csv')

# %%
df_target.drop(df_target.columns[0], axis=1)
# Out:
#                 id        lat       lon         tags  type
# 0        148680663  47.555612  9.688680  marketplace  node
# 1        240937972  50.965599  7.182943  marketplace  node
# 2        255897613  49.880786  8.660928  marketplace  node
# 3        276043329  53.327598  9.878438  marketplace  node
# 4        293994974  53.093369  8.810666  marketplace  node
# ...            ...        ...       ...          ...   ...
# 134347  6858753102  53.169617  8.702026  post_office  node
# 134348  6859841376  49.849712  7.889525  post_office  node
# 134349  6862942160  49.394662  8.796487  post_office  node
# 134350  6863015079  49.838985  8.702550  post_office  node
# 134351  6866309847  50.761275  7.027630  post_office  node
#
# [134352 rows x 5 columns]

# %%
# choose columns
df_target = df_target[['id', 'lat', 'lon','tags']]
df_target.head(10)
# Out:
#           id        lat        lon         tags
# 0  148680663  47.555612   9.688680  marketplace
# 1  240937972  50.965599   7.182943  marketplace
# 2  255897613  49.880786   8.660928  marketplace
# 3  276043329  53.327598   9.878438  marketplace
# 4  293994974  53.093369   8.810666  marketplace
# 5  310254200  53.434488   8.821352  marketplace
# 6  359885958  50.391747   8.192193  marketplace
# 7  375779845  50.931824   7.025336  marketplace
# 8  392491700  53.586377  10.045311  marketplace
# 9  428178744  53.489726  10.181960  marketplace

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# Label Encoding the amenity types
labelencoder = LabelEncoder()
labelencoder.fit(df_target.iloc[:,3].values)
df_target.iloc[:,3]=labelencoder.transform(df_target.iloc[:,3])

# %%
df_target.head()
# Out:
#           id        lat       lon  tags
# 0  148680663  47.555612  9.688680     3
# 1  240937972  50.965599  7.182943     3
# 2  255897613  49.880786  8.660928     3
# 3  276043329  53.327598  9.878438     3
# 4  293994974  53.093369  8.810666     3

# %% [markdown]
# onehotencoder = OneHotEncoder(categorical_features = [3])
# df_target = onehotencoder.fit_transform(df_target).toarray()

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Performing Clustering using K means

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=1000,n_init=10,random_state=0)
    kmeans.fit(df_target)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.savefig('elbow.png')
plt.show()

# %%
# Let n_cluster be 6 and 8
kmeans = KMeans(n_clusters = 6, max_iter=10000,n_init=10,init = 'k-means++', random_state = 42)
prediction_val = kmeans.fit_predict(df_target.values)
#dropping the predicted value into the column name cluster
data['cluster']=prediction_val

# %%
cent = kmeans.cluster_centers_

# %%
#clust_labels = prediction_val
kmeans = pd.DataFrame(prediction_val)
df_target.insert((df_target.shape[1]),'kmeans',kmeans)

# %%
#Plot the clusters obtained using k means
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
scatter = ax.scatter(df_target['lat'],df_target['lon'],
                     c=kmeans[0],s=50)
ax.set_title('K-Means Clustering')
ax.set_xlabel('Latitudinal Position')
ax.set_ylabel('Longitudinal Position')
plt.colorbar(scatter)

# %%
ans = labelencoder.inverse_transform(prediction_val)

# %%
ans
# Out:
# array(['bank', 'bank', 'bank', ..., 'parking', 'parking', 'parking'],
#       dtype=object)

# %%
final_df=pd.DataFrame({'id':df_target['id'].values,'lat':df_target['lat'].values,'lon':df_target['lon'].values,'tags':df_target['tags'].values,'cluster':ans})

# %%
final_df.head()
# Out:
#           id        lat       lon  tags cluster
# 0  148680663  47.555612  9.688680     3    bank
# 1  240937972  50.965599  7.182943     3    bank
# 2  255897613  49.880786  8.660928     3    bank
# 3  276043329  53.327598  9.878438     3    bank
# 4  293994974  53.093369  8.810666     3    bank

# %%
final_df.to_csv('knn_Geo.csv',index=False)

# %% [markdown]
# # Finish
