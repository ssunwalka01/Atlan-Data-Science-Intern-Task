# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="marketplace"](area);
 way["amenity"="marketplace"](area);
 rel["amenity"="marketplace"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data=response.json()
df = pd.DataFrame(data['elements'])

# %%
df.head()
# Out:
#           id        lat       lon  \
# 0  148680663  47.555612  9.688680
# 1  240937972  50.965599  7.182944
# 2  255897613  49.880786  8.660928
# 3  276043329  53.327598  9.878438
# 4  293994974  53.093369  8.810666
#
#                                                 tags  type
# 0  {'amenity': 'marketplace', 'description': 'Ler...  node
# 1  {'amenity': 'marketplace', 'name': 'Burgwinkel...  node
# 2  {'addr:city': 'Darmstadt', 'amenity': 'marketp...  node
# 3   {'amenity': 'marketplace', 'name': 'Marktplatz'}  node
# 4  {'amenity': 'marketplace', 'name': 'Findorffma...  node

# %%
df['tags'] = 'marketplace'

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="fuel"](area);
 way["amenity"="fuel"](area);
 rel["amenity"="fuel"](area);
);
out center;
"""
response1 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data1=response1.json()
df1 = pd.DataFrame(data1['elements'])
df1['tags'] = 'fuel'
df.head()
# Out:
#           id        lat       lon         tags  type
# 0  148680663  47.555612  9.688680  marketplace  node
# 1  240937972  50.965599  7.182944  marketplace  node
# 2  255897613  49.880786  8.660928  marketplace  node
# 3  276043329  53.327598  9.878438  marketplace  node
# 4  293994974  53.093369  8.810666  marketplace  node

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="cafe"](area);
 way["amenity"="cafe"](area);
 rel["amenity"="cafe"](area);
);
out center;
"""
response2 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data2=response2.json()
df2 = pd.DataFrame(data2['elements'])
df2['tags'] = 'cafe'
df2.head()
# Out:
#          id        lat        lon  tags  type
# 0    661339  48.103939  11.488255  cafe  node
# 1  21257562  50.859025  13.167652  cafe  node
# 2  26309934  50.119731  11.388971  cafe  node
# 3  29991932  49.015536   8.397546  cafe  node
# 4  30012754  52.538855  13.396097  cafe  node

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="parking"](area);
 way["amenity"="parking"](area);
 rel["amenity"="parking"](area);
);
out center;
"""
response3 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data3=response3.json()
df3 = pd.DataFrame(data3['elements'])
df3['tags'] = 'parking'
df3.head()
# Out:
#         id        lat       lon     tags  type
# 0   531550  49.878222  8.657972  parking  node
# 1   631662  49.813508  8.648890  parking  node
# 2   651192  49.881361  8.646917  parking  node
# 3  2455376  50.003178  8.990831  parking  node
# 4  9323857  47.714818  7.653783  parking  node

# %%
new = pd.concat([df,df1,df2,df3],axis=0)

# %%
new.head()
# Out:
#           id        lat       lon         tags  type
# 0  148680663  47.555612  9.688680  marketplace  node
# 1  240937972  50.965599  7.182944  marketplace  node
# 2  255897613  49.880786  8.660928  marketplace  node
# 3  276043329  53.327598  9.878438  marketplace  node
# 4  293994974  53.093369  8.810666  marketplace  node

# %%
new.to_csv("try.csv")

# %%
df=df1=df2=df3=[]
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="school"](area);
 way["amenity"="school"](area);
 rel["amenity"="school"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data=response.json()
df = pd.DataFrame(data['elements'])
df['tags'] = 'school'
df.head()
# Out:
#          id        lat       lon    tags  type
# 0  24470269  48.976183  8.414097  school  node
# 1  25929965  49.009291  8.432334  school  node
# 2  25976049  51.449116  6.660396  school  node
# 3  26009648  51.450805  6.647221  school  node
# 4  26009799  51.456106  6.654199  school  node

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="bank"](area);
 way["amenity"="bank"](area);
 rel["amenity"="bank"](area);
);
out center;
"""
response1 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data1=response1.json()
df1 = pd.DataFrame(data1['elements'])
df1['tags'] = 'bank'
df1.head()
# Out:
#          id        lat       lon  tags  type
# 0  16463150  49.550363  8.672208  bank  node
# 1  25185398  48.972136  8.404875  bank  node
# 2  25187718  48.971007  8.404962  bank  node
# 3  25508365  48.953803  8.508875  bank  node
# 4  25508368  48.953083  8.509484  bank  node

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="theatre"](area);
 way["amenity"="theatre"](area);
 rel["amenity"="theatre"](area);
);
out center;
"""
response2 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data2=response2.json()
df2 = pd.DataFrame(data2['elements'])
df2['tags'] = 'theatre'
df2.head()
# Out:
#          id        lat        lon     tags  type
# 0  22179552  52.981728   8.849281  theatre  node
# 1  25393506  53.864975  10.692441  theatre  node
# 2  26022810  51.337641  12.333334  theatre  node
# 3  26022926  51.336158  12.339108  theatre  node
# 4  30206383  49.631839   8.360794  theatre  node

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="post_office"](area);
 way["amenity"="post_office"](area);
 rel["amenity"="post_office"](area);
);
out center;
"""
response3 = requests.get(overpass_url, 
                        params={'data': overpass_query})
data3=response3.json()
df3 = pd.DataFrame(data3['elements'])
df3['tags'] = 'post_office'
df3.head()
# Out:
#          id        lat        lon         tags  type
# 0  21294479  50.109300  11.452395  post_office  node
# 1  21876758  52.983044   8.849149  post_office  node
# 2  25187743  48.976540   8.407402  post_office  node
# 3  25236916  47.988364   7.847346  post_office  node
# 4  25393516  53.867324  10.688997  post_office  node

# %%
new1 = pd.concat([new,df,df1,df2,df3],axis=0)
new1.to_csv("Data_1.csv")

# %% [markdown]
# ## OLD

# %%
df_target=pd.read_csv('Data_1.csv')

# %%
df_target.drop(df_target.columns[0], axis=1)
# Out:
#                 id        lat        lon         tags  type
# 0        148680663  47.555612   9.688680  marketplace  node
# 1        240937972  50.965599   7.182943  marketplace  node
# 2        255897613  49.880786   8.660928  marketplace  node
# 3        276043329  53.327598   9.878438  marketplace  node
# 4        293994974  53.093369   8.810666  marketplace  node
# 5        310254200  53.434488   8.821352  marketplace  node
# 6        359885958  50.391747   8.192193  marketplace  node
# 7        375779845  50.931824   7.025336  marketplace  node
# 8        392491700  53.586377  10.045311  marketplace  node
# 9        428178744  53.489726  10.181960  marketplace  node
# 10       428178747  53.487030  10.180763  marketplace  node
# 11       437149591  51.330629   6.609308  marketplace  node
# 12       470284840  52.407651  10.939739  marketplace  node
# 13       485130970  53.352258  12.578368  marketplace  node
# 14       494425713  51.652438   7.339383  marketplace  node
# 15       530184460  50.886746  10.011255  marketplace  node
# 16       570075098  50.685627   7.155765  marketplace  node
# 17       599200236  50.960080   7.990574  marketplace  node
# 18       610815055  51.219213   6.848935  marketplace  node
# 19       611733099  48.641243   8.895738  marketplace  node
# 20       635020668  50.119777   8.652555  marketplace  node
# 21       663913845  47.864354   9.174773  marketplace  node
# 22       665546624  50.796944   7.207212  marketplace  node
# 23       690282909  51.537153   6.972374  marketplace  node
# 24       699564298  51.520643   6.925757  marketplace  node
# 25       705170789  48.110220  11.595945  marketplace  node
# 26       728378424  50.648196   7.527862  marketplace  node
# 27       738094602  52.423236  13.475302  marketplace  node
# 28       813320103  51.664069   7.133086  marketplace  node
# 29       837272528  50.433523   7.671752  marketplace  node
# ...            ...        ...        ...          ...   ...
# 134322  6823031050  51.163419  13.571954  post_office  node
# 134323  6823120800  51.108346  10.648024  post_office  node
# 134324  6823844424  49.471847  11.105764  post_office  node
# 134325  6824678938  50.660640  13.336826  post_office  node
# 134326  6827231264  48.329266   9.932381  post_office  node
# 134327  6828255285  48.394814  10.831553  post_office  node
# 134328  6830503044  52.891806  10.655661  post_office  node
# 134329  6831417146  49.475212   8.663246  post_office  node
# 134330  6832427987  47.985190   7.847678  post_office  node
# 134331  6832731040  47.913475   9.744798  post_office  node
# 134332  6832764094  52.150746   9.949379  post_office  node
# 134333  6833041614  49.780921   9.935356  post_office  node
# 134334  6835537781  48.653121   7.926852  post_office  node
# 134335  6837628722  48.666699   7.941510  post_office  node
# 134336  6838865736  50.768510   8.585378  post_office  node
# 134337  6841713317  49.300960   7.369015  post_office  node
# 134338  6842730695  53.690199   7.802546  post_office  node
# 134339  6844035279  48.932910  12.197350  post_office  node
# 134340  6847840337  49.672670  12.331165  post_office  node
# 134341  6851404444  50.082447   8.222876  post_office  node
# 134342  6853525422  49.345636   7.365070  post_office  node
# 134343  6855750503  47.985615   7.836732  post_office  node
# 134344  6857025216  49.984141   8.245370  post_office  node
# 134345  6858274619  53.143218   8.194057  post_office  node
# 134346  6858406180  50.556632   6.764936  post_office  node
# 134347  6858753102  53.169617   8.702026  post_office  node
# 134348  6859841376  49.849712   7.889525  post_office  node
# 134349  6862942160  49.394662   8.796487  post_office  node
# 134350  6863015079  49.838985   8.702550  post_office  node
# 134351  6866309847  50.761275   7.027630  post_office  node
#
# [134352 rows x 5 columns]

# %%
# choose columns
df_target = df_target[['id', 'lat', 'lon','tags']]
df_target.head(10)
# Out:
#           id        lat        lon         tags
# 0  148680663  47.555612   9.688680  marketplace
# 1  240937972  50.965599   7.182943  marketplace
# 2  255897613  49.880786   8.660928  marketplace
# 3  276043329  53.327598   9.878438  marketplace
# 4  293994974  53.093369   8.810666  marketplace
# 5  310254200  53.434488   8.821352  marketplace
# 6  359885958  50.391747   8.192193  marketplace
# 7  375779845  50.931824   7.025336  marketplace
# 8  392491700  53.586377  10.045311  marketplace
# 9  428178744  53.489726  10.181960  marketplace

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# Label Encoding the amenity types
labelencoder = LabelEncoder()
labelencoder.fit(df_target.iloc[:,3].values)
df_target.iloc[:,3]=labelencoder.transform(df_target.iloc[:,3])

# %%
df_target.head()
# Out:
#           id        lat       lon  tags
# 0  148680663  47.555612  9.688680     3
# 1  240937972  50.965599  7.182943     3
# 2  255897613  49.880786  8.660928     3
# 3  276043329  53.327598  9.878438     3
# 4  293994974  53.093369  8.810666     3

# %% [markdown]
# onehotencoder = OneHotEncoder(categorical_features = [3])
# df_target = onehotencoder.fit_transform(df_target).toarray()

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Performing Clustering using K means

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=600,n_init=10,random_state=0)
    kmeans.fit(df_target)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.savefig('elbow.png')
plt.show()

# %%
# Let n_cluster be 6 and 8
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
prediction_val = kmeans.fit_predict(df_target.values)
#dropping the predicted value into the column name cluster
data['cluster']=prediction_val
cent = kmeans.cluster_centers_

# %%
cent = kmeans.cluster_centers_

# %%
#clust_labels = prediction_val
kmeans = pd.DataFrame(prediction_val)
df_target.insert((df_target.shape[1]),'kmeans',kmeans)

# %%
#Plot the clusters obtained using k means
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(df_target['lat'],df_target['lon'],
                     c=kmeans[0],s=50)
ax.set_title('K-Means Clustering')
ax.set_xlabel('Latitudinal Position')
ax.set_ylabel('Longitudinal Position')
plt.colorbar(scatter)

# %%
ans = labelencoder.inverse_transform(prediction_val)

# %%
ans
# Out:
# array(['fuel', 'fuel', 'fuel', ..., 'cafe', 'cafe', 'cafe'], dtype=object)

# %%
final_df=pd.DataFrame({'id':df_target['id'].values,'lat':df_target['lat'].values,'lon':df_target['lon'].values,'tags':df_target['tags'].values,'cluster':ans})

# %%
final_df.head()
# Out:
#           id        lat       lon  tags cluster
# 0  148680663  47.555612  9.688680     3    fuel
# 1  240937972  50.965599  7.182943     3    fuel
# 2  255897613  49.880786  8.660928     3    fuel
# 3  276043329  53.327598  9.878438     3    fuel
# 4  293994974  53.093369  8.810666     3    fuel

# %%
final_df.to_csv('knn_Geo.csv',index=False)

# %% [markdown]
# # Finish
